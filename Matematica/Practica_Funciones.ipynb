# %% [markdown]
# ## Práctica Funciones en Python

# %% [markdown]
# Se le entregan las siguientes 3 funciones, cuyo dominio son todos los números reales entre -1 y 10:
#
# **Función 1**: $$f(x) = x^{2}-2x+7$$
#
# **Función 2**: $$g(x) = 3x+9$$
#
# **Función 3**: $$h(x) = 2e^{0.4x}$$

# %% [markdown]
# ## Actividades

# %% [markdown]
# 1. Defina las 3 funciones en Python. Calcule la imagen de $$x=6$$ en cada una de ellas.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import fsolve

x=6

def f(x):
    return x**2-2*x+7
print(f(x))

def g(x):
    return 3*x+9
print(g(x))

def h(x):
    return 2*np.exp(0.4*x)
print(round(h(x),2))
# Out:
# 31
# 27
# 22.05

# %% [markdown]
# 2. Calcule la preimagen de $$y=20$$ en cada una de ellas.

# %%
# import numpy as np
# import matplotlib.pyplot as plt
# from scipy.optimize import fsolve

# def f(x):
#     return x**2-2*x+7-20
# xo=np.linspace(-1, 10, 2)
# solucion=fsolve(f, xo)
# print(np.round(solucion,2))

# def g(x):
#     return 3*x+9-20
# xo=np.linspace(-1, 10, 1)
# solucion1=fsolve(g, xo)
# print(np.round(solucion1,2))

# def h(x):
#     return 2*np.exp(0.4*x)-20
# xo=np.linspace(-1, 10, 3)
# solucion2=fsolve(h, xo)
# print(np.round(solucion2,2))
# Out:
# [-2.74  4.74]
# [3.67]
# [-815.86    5.76    5.76]

# %% [markdown]
# 3. Grafique las 3 funciones en un mismo gráfico, visualizando de acuerdo al dominio mencionado, y mostrando una etiqueta que permita identificar a cada función.

# %%
x = np.arange(-1,10,0.2)
plt.plot(x, f(x), label = 'f(x)')
plt.plot(x, g(x), label = 'g(x)')
plt.plot(x, h(x), label = 'h(x)')
# plt.axis([inicialx,finalx,inicialy,finaly])
plt.title('Grafica de las funciones')
plt.xlabel('eje X')
plt.ylabel('eje Y')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# 4. Determine en qué punto se intersectan las funciones g y h.

# %%
def A(x):
    return g(x)-h(x)
xo=np.linspace(0,10,2)
solucion3=fsolve(A, xo)
print(solucion3)
# Out:
# [-2.78080346  6.69188515]

# %%
def g(x):
    return 3*x+9
print(round(g(solucion3[1]),2))

def h(x):
    return 2*np.exp(0.4*x)
print(round(h(solucion3[1]),2))
# Out:
# 29.08
# 29.08

# %% [markdown]
# 5. Determine en qué puntos se intersectan las funciones f y g.

# %%
def B(x):
    return f(x)-g(x)
xo=np.linspace(-1,10,2)
solucion=fsolve(B, xo)
print(solucion)
# Out:
# [-0.37228132  5.37228132]

# %%
def f(x):
    return x**2-2*x+7
print(round(f(solucion4[1]),2))

def g(x):
    return 3*x+9
print(round(g(solucion4[1]),2))
# Out:
# 25.12
# 25.12
